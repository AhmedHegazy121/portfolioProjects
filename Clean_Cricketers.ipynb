# %%
import pandas as pd

# %% [markdown]
# Read file

# %%
df = pd.read_csv(r"D:\Portfolio\New\clean\New.csv")

# %%
df
# Out:
#                Player       Span   Mat  Inns    NO    Runs    HS    Ave  \
# 0    DG Bradman (AUS)  1928-1948  52.0  80.0  10.0  6996.0   334  99.94
# 1      AC Voges (AUS)  2015-2016  20.0  31.0   7.0  1485.0  269*  61.87
# 2     RG Pollock (SA)  1963-1970  23.0  41.0   4.0  2256.0   274  60.97
# 3     GA Headley (WI)  1930-1954  22.0  40.0   4.0  2190.0  270*  60.83
# 4   H Sutcliffe (ENG)  1924-1935  54.0  84.0   9.0  4555.0   194  60.73
# ..                ...        ...   ...   ...   ...     ...   ...    ...
# 63  WH Ponsford (AUS)  1924-1934  29.0  48.0   4.0  2122.0   266  48.22
# 64  WH Ponsford (AUS)  1924-1934  29.0  48.0   4.0  2122.0   266  48.22
# 65    SJ McCabe (AUS)  1930-1938  39.0  62.0   5.0  2748.0   232  48.21
# 66   DR Jardine (ENG)  1928-1934  22.0  33.0   6.0  1296.0   127  48.00
# 67                NaN        NaN   NaN   NaN   NaN     NaN   NaN    NaN
#
#        BF     SR   100    50    0     4s    6s
# 0   9800+  58.60  29.0  13.0  7.0  626.0   6.0
# ...

# %% [markdown]
# Rename Multiple Columns in a list

# %%
df= df.rename(columns={"Mat":"matches_played","Inns":"innings_batted","NO":"not_outs","HS":"highest_inns_score","BF":"balls_faced","SR":"batting_strike_rate"})

# %%
df.head()
# Out:
#               Player       Span  matches_played  innings_batted  not_outs  \
# 0   DG Bradman (AUS)  1928-1948            52.0            80.0      10.0
# 1     AC Voges (AUS)  2015-2016            20.0            31.0       7.0
# 2    RG Pollock (SA)  1963-1970            23.0            41.0       4.0
# 3    GA Headley (WI)  1930-1954            22.0            40.0       4.0
# 4  H Sutcliffe (ENG)  1924-1935            54.0            84.0       9.0
#
#      Runs highest_inns_score    Ave balls_faced  batting_strike_rate   100  \
# 0  6996.0                334  99.94       9800+                58.60  29.0
# 1  1485.0               269*  61.87        2667                55.68   5.0
# 2  2256.0                274  60.97       1707+                54.48   7.0
# 3  2190.0               270*  60.83        416+                56.00  10.0
# 4  4555.0                194  60.73       6558+                34.59  16.0
#
#      50    0     4s    6s
# 0  13.0  7.0  626.0   6.0
# ...

# %% [markdown]
# Check null values

# %%
df.isnull().any()
# Out:
# Player                 True
# Span                   True
# matches_played         True
# innings_batted         True
# not_outs               True
# Runs                   True
# highest_inns_score     True
# Ave                    True
# balls_faced            True
# batting_strike_rate    True
# 100                    True
# 50                     True
# 0                      True
# 4s                     True
# 6s                     True
# dtype: bool

# %%
df[df["balls_faced"].isna()==1]
# Out:
#                   Player       Span  matches_played  innings_batted  not_outs  \
# 8         ED Weekes (WI)  1948-1958            48.0            81.0       5.0
# 14       CL Walcott (WI)  1948-1960            44.0            74.0       7.0
# 57  Hon.FS Jackson (ENG)  1893-1905            20.0            33.0       4.0
# 67                   NaN        NaN             NaN             NaN       NaN
#
#       Runs highest_inns_score    Ave balls_faced  batting_strike_rate   100  \
# 8   4455.0                207  58.61         NaN                  0.0  15.0
# 14  3798.0                220  56.68         NaN                  0.0  15.0
# 57  1415.0               144*  48.79         NaN                  0.0   5.0
# 67     NaN                NaN    NaN         NaN                  NaN   NaN
#
#       50    0     4s    6s
# 8   19.0  6.0  258.0   2.0
# 14  14.0  1.0  107.0  11.0
# 57   6.0  3.0   51.0   0.0
# 67   NaN  NaN    NaN   NaN

# %%
df["balls_faced"] = df["balls_faced"].fillna(0)

# %%
df["batting_strike_rate"] = df["batting_strike_rate"].fillna(0)

# %%
df[df["Player"]=="ED Weekes (WI)"]
# Out:
#            Player       Span  matches_played  innings_batted  not_outs  \
# 8  ED Weekes (WI)  1948-1958            48.0            81.0       5.0
#
#      Runs highest_inns_score    Ave balls_faced  batting_strike_rate   100  \
# 8  4455.0                207  58.61           0                  0.0  15.0
#
#      50    0     4s   6s
# 8  19.0  6.0  258.0  2.0

# %% [markdown]
# Drop duplicates

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 63    False
# 64     True
# 65    False
# 66    False
# 67    False
# Length: 68, dtype: bool

# %%
df[df["Player"].duplicated()==1] #show duplicate values
# Out:
#                  Player       Span  matches_played  innings_batted  not_outs  \
# 30     RT Ponting (AUS)  1995-2012           168.0           287.0      29.0
# 35   S Chanderpaul (WI)  1994-2015           164.0           280.0      49.0
# 45    DCS Compton (ENG)  1937-1957            78.0           131.0      15.0
# 59  TT Samaraweera (SL)  2001-2013            81.0           132.0      20.0
# 64    WH Ponsford (AUS)  1924-1934            29.0            48.0       4.0
#
#        Runs highest_inns_score    Ave balls_faced  batting_strike_rate   100  \
# 30  13378.0                257  51.85       22782                58.72  41.0
# 35  11867.0               203*  51.37       27395                43.31  30.0
# 45   5807.0                278  50.06       2731+                38.81  17.0
# 59   5462.0                231  48.76       11641                46.92  14.0
# 64   2122.0                266  48.22       3118+                44.77   7.0
#
#       50     0      4s    6s
# ...

# %%
df[df["Player"].isin(['RT Ponting (AUS)','S Chanderpaul (WI)','WH Ponsford (AUS)','TT Samaraweera (SL','DCS Compton (ENG'])]
# Out:
#                 Player       Span  matches_played  innings_batted  not_outs  \
# 29    RT Ponting (AUS)  1995-2012           168.0           287.0      29.0
# 30    RT Ponting (AUS)  1995-2012           168.0           287.0      29.0
# 34  S Chanderpaul (WI)  1994-2015           164.0           280.0      49.0
# 35  S Chanderpaul (WI)  1994-2015           164.0           280.0      49.0
# 63   WH Ponsford (AUS)  1924-1934            29.0            48.0       4.0
# 64   WH Ponsford (AUS)  1924-1934            29.0            48.0       4.0
#
#        Runs highest_inns_score    Ave balls_faced  batting_strike_rate   100  \
# 29  13378.0                257  51.85       22782                58.72  41.0
# 30  13378.0                257  51.85       22782                58.72  41.0
# 34  11867.0               203*  51.37       27395                43.31  30.0
# 35  11867.0               203*  51.37       27395                43.31  30.0
# ...

# %%
df = df.drop_duplicates()

# %%
df[df["Player"].isin(['RT Ponting (AUS)','S Chanderpaul (WI)','WH Ponsford (AUS)','TT Samaraweera (SL','DCS Compton (ENG'])]
# Out:
#                 Player       Span  matches_played  innings_batted  not_outs  \
# 29    RT Ponting (AUS)  1995-2012           168.0           287.0      29.0
# 34  S Chanderpaul (WI)  1994-2015           164.0           280.0      49.0
# 63   WH Ponsford (AUS)  1924-1934            29.0            48.0       4.0
#
#        Runs highest_inns_score    Ave balls_faced  batting_strike_rate   100  \
# 29  13378.0                257  51.85       22782                58.72  41.0
# 34  11867.0               203*  51.37       27395                43.31  30.0
# 63   2122.0                266  48.22       3118+                44.77   7.0
#
#       50     0      4s    6s
# 29  62.0  17.0  1509.0  73.0
# 34  66.0  15.0  1285.0  36.0
# 63   6.0   1.0   119.0   0.0

# %% [markdown]
# Splite up into starte and End Date

# %%
df['Span'].str.split(pat="-")
# Out:
# 0     [1928, 1948]
# 1     [2015, 2016]
# 2     [1963, 1970]
# 3     [1930, 1954]
# 4     [1924, 1935]
#           ...
# 62    [2002, 2014]
# 63    [1924, 1934]
# 65    [1930, 1938]
# 66    [1928, 1934]
# 67             NaN
# Name: Span, Length: 63, dtype: object

# %%
df['Rooki_year']=df['Span'].str.split(pat="-").str[0]

# %%
df['final_year']=df['Span'].str.split(pat="-").str[1]

# %%
df
# Out:
#                Player       Span  matches_played  innings_batted  not_outs  \
# 0    DG Bradman (AUS)  1928-1948            52.0            80.0      10.0
# 1      AC Voges (AUS)  2015-2016            20.0            31.0       7.0
# 2     RG Pollock (SA)  1963-1970            23.0            41.0       4.0
# 3     GA Headley (WI)  1930-1954            22.0            40.0       4.0
# 4   H Sutcliffe (ENG)  1924-1935            54.0            84.0       9.0
# ..                ...        ...             ...             ...       ...
# 62  GC Smith (ICC/SA)  2002-2014           117.0           205.0      13.0
# 63  WH Ponsford (AUS)  1924-1934            29.0            48.0       4.0
# 65    SJ McCabe (AUS)  1930-1938            39.0            62.0       5.0
# 66   DR Jardine (ENG)  1928-1934            22.0            33.0       6.0
# 67                NaN        NaN             NaN             NaN       NaN
#
# ...

# %%
df =df.drop(['Span'],axis= 1)

# %%
df
# Out:
#                Player  matches_played  innings_batted  not_outs    Runs  \
# 0    DG Bradman (AUS)            52.0            80.0      10.0  6996.0
# 1      AC Voges (AUS)            20.0            31.0       7.0  1485.0
# 2     RG Pollock (SA)            23.0            41.0       4.0  2256.0
# 3     GA Headley (WI)            22.0            40.0       4.0  2190.0
# 4   H Sutcliffe (ENG)            54.0            84.0       9.0  4555.0
# ..                ...             ...             ...       ...     ...
# 62  GC Smith (ICC/SA)           117.0           205.0      13.0  9265.0
# 63  WH Ponsford (AUS)            29.0            48.0       4.0  2122.0
# 65    SJ McCabe (AUS)            39.0            62.0       5.0  2748.0
# 66   DR Jardine (ENG)            22.0            33.0       6.0  1296.0
# 67                NaN             NaN             NaN       NaN     NaN
#
#    highest_inns_score    Ave balls_faced  batting_strike_rate   100    50  \
# ...

# %%
df = df.drop(index=67)
df
# Out:
#                Player  matches_played  innings_batted  not_outs    Runs  \
# 0    DG Bradman (AUS)            52.0            80.0      10.0  6996.0
# 1      AC Voges (AUS)            20.0            31.0       7.0  1485.0
# 2     RG Pollock (SA)            23.0            41.0       4.0  2256.0
# 3     GA Headley (WI)            22.0            40.0       4.0  2190.0
# 4   H Sutcliffe (ENG)            54.0            84.0       9.0  4555.0
# ..                ...             ...             ...       ...     ...
# 61   KD Walters (AUS)            74.0           125.0      14.0  5357.0
# 62  GC Smith (ICC/SA)           117.0           205.0      13.0  9265.0
# 63  WH Ponsford (AUS)            29.0            48.0       4.0  2122.0
# 65    SJ McCabe (AUS)            39.0            62.0       5.0  2748.0
# 66   DR Jardine (ENG)            22.0            33.0       6.0  1296.0
#
#    highest_inns_score    Ave balls_faced  batting_strike_rate   100    50  \
# ...

# %%
# spilte the country from players
df['Player'].str.split('(')
# Out:
# 0      [DG Bradman , AUS)]
# 1        [AC Voges , AUS)]
# 2       [RG Pollock , SA)]
# 3       [GA Headley , WI)]
# 4     [H Sutcliffe , ENG)]
#               ...
# 61     [KD Walters , AUS)]
# 62    [GC Smith , ICC/SA)]
# 63    [WH Ponsford , AUS)]
# 65      [SJ McCabe , AUS)]
# 66     [DR Jardine , ENG)]
# Name: Player, Length: 62, dtype: object

# %%
df['country']=df['Player'].str.split("(").str[1]

# %%
df['country'] = df['country'].str.split(")").str[0]

# %%
df['country']
# Out:
# 0        AUS
# 1        AUS
# 2         SA
# 3         WI
# 4        ENG
#        ...
# 61       AUS
# 62    ICC/SA
# 63       AUS
# 65       AUS
# 66       ENG
# Name: country, Length: 62, dtype: object

# %%
df['Player'] = df['Player'].str.split('(').str[0]

# %%
df['Player']
# Out:
# 0      DG Bradman
# 1        AC Voges
# 2      RG Pollock
# 3      GA Headley
# 4     H Sutcliffe
#           ...
# 61     KD Walters
# 62       GC Smith
# 63    WH Ponsford
# 65      SJ McCabe
# 66     DR Jardine
# Name: Player, Length: 62, dtype: object

# %% [markdown]
# Change Data types

# %%
df.dtypes # check data types
# Out:
# Player                  object
# matches_played         float64
# innings_batted         float64
# not_outs               float64
# Runs                   float64
# highest_inns_score      object
# Ave                    float64
# balls_faced             object
# batting_strike_rate    float64
# 100                    float64
# 50                     float64
# 0                      float64
# 4s                     float64
# 6s                     float64
# Rooki_year              object
# final_year              object
# country                 object
# dtype: object

# %%
df
# Out:
#           Player  matches_played  innings_batted  not_outs    Runs  \
# 0    DG Bradman             52.0            80.0      10.0  6996.0
# 1      AC Voges             20.0            31.0       7.0  1485.0
# 2    RG Pollock             23.0            41.0       4.0  2256.0
# 3    GA Headley             22.0            40.0       4.0  2190.0
# 4   H Sutcliffe             54.0            84.0       9.0  4555.0
# ..           ...             ...             ...       ...     ...
# 61   KD Walters             74.0           125.0      14.0  5357.0
# 62     GC Smith            117.0           205.0      13.0  9265.0
# 63  WH Ponsford             29.0            48.0       4.0  2122.0
# 65    SJ McCabe             39.0            62.0       5.0  2748.0
# 66   DR Jardine             22.0            33.0       6.0  1296.0
#
#    highest_inns_score    Ave balls_faced  batting_strike_rate   100    50  \
# 0                 334  99.94       9800+                58.60  29.0  13.0
# ...

# %%
df['highest_inns_score'].str.split("*").str[0]
# Out:
# 0     334
# 1     269
# 2     274
# 3     270
# 4     194
#      ...
# 61    250
# 62    277
# 63    266
# 65    232
# 66    127
# Name: highest_inns_score, Length: 62, dtype: object

# %%
df['highest_inns_score']= df['highest_inns_score'].str.split("*").str[0]

# %%
df['highest_inns_score'].astype("int")
# Out:
# 0     334
# 1     269
# 2     274
# 3     270
# 4     194
#      ...
# 61    250
# 62    277
# 63    266
# 65    232
# 66    127
# Name: highest_inns_score, Length: 62, dtype: int32

# %%
df['highest_inns_score'] = df['highest_inns_score'].astype("int")

# %% [markdown]
# fix Rooki_year and final_yeat

# %%
df = df.astype({'Rooki_year':'int','final_year':'int'})
df.dtypes
# Out:
# Player                  object
# matches_played         float64
# innings_batted         float64
# not_outs               float64
# Runs                   float64
# highest_inns_score       int32
# Ave                    float64
# balls_faced             object
# batting_strike_rate    float64
# 100                    float64
# 50                     float64
# 0                      float64
# 4s                     float64
# 6s                     float64
# Rooki_year               int32
# final_year               int32
# country                 object
# dtype: object

# %%
df['matches_played'] = df['matches_played'].astype("int")

# %%
df.dtypes
# Out:
# Player                  object
# matches_played           int32
# innings_batted         float64
# not_outs               float64
# Runs                   float64
# highest_inns_score       int32
# Ave                    float64
# balls_faced             object
# batting_strike_rate    float64
# 100                    float64
# 50                     float64
# 0                      float64
# 4s                     float64
# 6s                     float64
# Rooki_year               int32
# final_year               int32
# country                 object
# dtype: object

# %%
df.head()
# Out:
#          Player  matches_played  innings_batted  not_outs    Runs  \
# 0   DG Bradman               52            80.0      10.0  6996.0
# 1     AC Voges               20            31.0       7.0  1485.0
# 2   RG Pollock               23            41.0       4.0  2256.0
# 3   GA Headley               22            40.0       4.0  2190.0
# 4  H Sutcliffe               54            84.0       9.0  4555.0
#
#    highest_inns_score    Ave balls_faced  batting_strike_rate   100    50  \
# 0                 334  99.94       9800+                58.60  29.0  13.0
# 1                 269  61.87        2667                55.68   5.0   4.0
# 2                 274  60.97       1707+                54.48   7.0  11.0
# 3                 270  60.83        416+                56.00  10.0   5.0
# 4                 194  60.73       6558+                34.59  16.0  23.0
#
#      0     4s    6s  Rooki_year  final_year country
# 0  7.0  626.0   6.0        1928        1948     AUS
# ...

# %%
df=df.astype({'100':'int','50':'int' ,'0':'int','4s':'int','6s':'int','innings_batted':'int','not_outs':'int','Runs':'int'})

# %%
df.dtypes
# Out:
# Player                  object
# matches_played           int32
# innings_batted           int32
# not_outs                 int32
# Runs                     int32
# highest_inns_score       int32
# Ave                    float64
# balls_faced              int32
# batting_strike_rate    float64
# 100                      int32
# 50                       int32
# 0                        int32
# 4s                       int32
# 6s                       int32
# Rooki_year               int32
# final_year               int32
# country                 object
# dtype: object

# %% [markdown]
# this code will spilte  the value + and then fill the nul value with zero  so we can convert to int

# %%
df['balls_faced']=df['balls_faced'].str.split('+').str[0].fillna(0).astype("int")

# %%
df.dtypes
# Out:
# Player                  object
# matches_played           int32
# innings_batted           int32
# not_outs                 int32
# Runs                     int32
# highest_inns_score       int32
# Ave                    float64
# balls_faced              int32
# batting_strike_rate    float64
# 100                      int32
# 50                       int32
# 0                        int32
# 4s                       int32
# 6s                       int32
# Rooki_year               int32
# final_year               int32
# country                 object
# dtype: object

# %%
df
# Out:
#           Player  matches_played  innings_batted  not_outs    Runs  \
# 0    DG Bradman               52            80.0      10.0  6996.0
# 1      AC Voges               20            31.0       7.0  1485.0
# 2    RG Pollock               23            41.0       4.0  2256.0
# 3    GA Headley               22            40.0       4.0  2190.0
# 4   H Sutcliffe               54            84.0       9.0  4555.0
# ..           ...             ...             ...       ...     ...
# 61   KD Walters               74           125.0      14.0  5357.0
# 62     GC Smith              117           205.0      13.0  9265.0
# 63  WH Ponsford               29            48.0       4.0  2122.0
# 65    SJ McCabe               39            62.0       5.0  2748.0
# 66   DR Jardine               22            33.0       6.0  1296.0
#
#     highest_inns_score    Ave  balls_faced  batting_strike_rate   100    50  \
# 0                  334  99.94         9800                58.60  29.0  13.0
# ...

# %% [markdown]
# career_lenghth colums

# %%
df['Career_length'] = df['final_year'] - df['Rooki_year']

# %%
df.head()
# Out:
#          Player  matches_played  innings_batted  not_outs  Runs  \
# 0   DG Bradman               52              80        10  6996
# 1     AC Voges               20              31         7  1485
# 2   RG Pollock               23              41         4  2256
# 3   GA Headley               22              40         4  2190
# 4  H Sutcliffe               54              84         9  4555
#
#    highest_inns_score    Ave  balls_faced  batting_strike_rate  100  50  0  \
# 0                 334  99.94         9800                58.60   29  13  7
# 1                 269  61.87         2667                55.68    5   4  2
# 2                 274  60.97         1707                54.48    7  11  1
# 3                 270  60.83          416                56.00   10   5  2
# 4                 194  60.73         6558                34.59   16  23  2
#
#     4s  6s  Rooki_year  final_year country  Career_length
# 0  626   6        1928        1948     AUS             20
# ...

# %%
pd.set_option('display.max_rows' , None)
df
# Out:
#                Player  matches_played  innings_batted  not_outs   Runs  \
# 0         DG Bradman               52              80        10   6996
# 1           AC Voges               20              31         7   1485
# 2         RG Pollock               23              41         4   2256
# 3         GA Headley               22              40         4   2190
# 4        H Sutcliffe               54              84         9   4555
# 5           HC Brook               15              24         1   1378
# 6          E Paynter               20              31         5   1540
# 7      KF Barrington               82             131        15   6806
# 8          ED Weekes               48              81         5   4455
# 9         WR Hammond               85             140        16   7249
# 10         GS Sobers               93             160        21   8032
# 11     KC Sangakkara              134             233        17  12400
# ...

# %% [markdown]
# Calculations with data frame

# %%
 # what is the average career length
df['Career_length'].mean()
# Out:
# 13.209677419354838

# %%
#AVg  batting_strike_rate FOR CRICTERS WHO PLAYED OVER 10 YEARS
df[df['Career_length']>10]['batting_strike_rate'].mean() # if  career length greater than 10 Display baattin that is  their career greater than 10
# Out:
# 47.95113636363636

# %%
#find number of cricketers who played before 1960
df[df['Rooki_year'] < 1960]['Player'].count()
# Out:
# 23

# %%
#max highest Inns score by country
df.groupby('country')['highest_inns_score'].max().to_frame('Highinncountry').reset_index().sort_values('Highinncountry', ascending=False)
# Out:
#     country  Highinncountry
# 5    ICC/WI             400
# 0       AUS             380
# 10       SL             374
# 11       WI             365
# 1       ENG             364
# 3   ICC/PAK             329
# 2   ICC/IND             319
# 8       PAK             313
# 9        SA             278
# 4    ICC/SA             277
# 6       IND             254
# 7        NZ             251
# 12      ZIM             232

# %%
#5 hundreds , fifties , ducks (0) AVG by country
df.groupby('country')[['100','50','0']].mean()
# Out:
#                100         50          0
# country
# AUS      20.625000  28.375000   8.562500
# ENG      12.538462  21.076923   4.307692
# ICC/IND  29.500000  47.500000  12.000000
# ICC/PAK  25.000000  46.000000  15.000000
# ICC/SA   36.000000  48.000000  13.500000
# ICC/WI   34.000000  48.000000  17.000000
# IND      29.500000  36.500000  10.750000
# NZ       18.500000  22.000000   6.000000
# PAK      21.250000  28.000000   9.500000
# SA        9.800000  20.200000   3.400000
# SL       28.666667  44.000000  12.333333
# WI       16.625000  25.625000   7.250000
# ZIM      12.000000  27.000000   5.000000
